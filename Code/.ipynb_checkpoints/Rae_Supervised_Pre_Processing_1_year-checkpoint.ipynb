# %%
import pandas as pd
from pathlib import Path
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# Read etf_1_years_complete_df.csv
file_path = Path("../Data/Unsupervised/etf_1_years_complete_df.csv")
etf_1_years_complete_df = pd.read_csv(file_path, index_col="ETF Names")

etf_1_years_complete_df.head()
# Out:
#                                                     30-Jun-21  31-Jul-21  \
# ETF Names
# iShares Asia 50 ETF                                      3.92      -6.44
# iShares China Large-Cap ETF                              3.60     -10.63
# iShares Core Cash ETF                                    0.00       0.00
# iShares Core Composite Bond ETF                          0.68       1.75
# iShares Core Global Corporate Bond (AUD Hedged)...       1.09       1.17
#
#                                                     31-Aug-21  30-Sep-21  \
# ETF Names
# iShares Asia 50 ETF                                     -0.44      -4.79
# iShares China Large-Cap ETF                              1.57      -3.79
# iShares Core Cash ETF                                    0.00       0.00
# iShares Core Composite Bond ETF                          0.09      -1.53
# iShares Core Global Corporate Bond (AUD Hedged)...      -0.24      -1.19
#
# ...

# %%
# Calculate PCT_Cumulative_Returns
## Drop STD and Class for Cumulative Returns calculation
dropped_etf_1_years_complete_df = etf_1_years_complete_df.drop(columns=["STD_2021_2022", "Class"])
dropped_etf_1_years_complete_df.head()

## Transpose dropped_etf_1_years_complete_df for Cumulative Returns calculation
flipped = np.transpose(dropped_etf_1_years_complete_df)
flipped.head()

## Create new Dataframe for loop in Cumulative Returns calculation
cr = pd.DataFrame()

## Create loop to calculate Cumulative Returns column by column
for col in flipped.columns:
    cret = flipped[col].cumprod(axis=0)
    cr[col] = cret

# Calculate Cumulative Returns as a percentage ///// check
pct_cr = cr*100

# %%
# Add a PCT_Cumulative_Returns column to etf_1_years_complete_df

## Transpose back for concat with etf_1_years_complete_df
flipback = np.transpose(pct_cr.iloc[-1])

## Create new Dataframe and populate with Cumulative Returns column
pct_cr_dropped_etf_1_years_complete_df = pd.DataFrame(flipback)

## Rename column 30-Jun-22 in pct_cumulative_returns_dropped_etf_1_years_complete_df to PCT_Cumulative_Returns
pct_cr_dropped_etf_1_years_complete_df = pct_cr_dropped_etf_1_years_complete_df.rename(columns={
    "30-Jun-22": "PCT_Cumulative_Returns"
})

## Concat etf_1_years_complete_df with pct_cumulative_returns_dropped_etf_1_years_complete_df
pct_cr_etf_1_years_complete_df = pd.concat([etf_1_years_complete_df, pct_cr_dropped_etf_1_years_complete_df], axis=1)

# Check pct_cr_etf_1_years_complete_df
pct_cr_etf_1_years_complete_df.head()
# Out:
#                                                     30-Jun-21  31-Jul-21  \
# iShares Asia 50 ETF                                      3.92      -6.44
# iShares China Large-Cap ETF                              3.60     -10.63
# iShares Core Cash ETF                                    0.00       0.00
# iShares Core Composite Bond ETF                          0.68       1.75
# iShares Core Global Corporate Bond (AUD Hedged)...       1.09       1.17
#
#                                                     31-Aug-21  30-Sep-21  \
# iShares Asia 50 ETF                                     -0.44      -4.79
# iShares China Large-Cap ETF                              1.57      -3.79
# iShares Core Cash ETF                                    0.00       0.00
# iShares Core Composite Bond ETF                          0.09      -1.53
# iShares Core Global Corporate Bond (AUD Hedged)...      -0.24      -1.19
#
#                                                     31-Oct-21  30-Nov-21  \
# ...

# %%
# Create Loop to determine if PCT_Cumulative_Returns is equal to or greater than 6%  and add column with output //// check
for rows in pct_cr_etf_1_years_complete_df["PCT_Cumulative_Returns"]:
    if rows > 6:
        check = True 
    elif rows < 6:
        check = False
    elif rows == 6:
        check = True
    
    pct_cr_etf_1_years_complete_df["Target_met"] = check

# %%
# classification stuff on gitlab
